# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('athlete_events.csv')

df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    269731
# True       1385
# dtype: int64

# %% [markdown]
# ### the percentage of females to males

# %%
df['Sex'].value_counts(normalize=True)
# Out:
# M    0.725129
# F    0.274871
# Name: Sex, dtype: float64

# %%
sns.countplot(data=df,x='Medal',hue='Sex')
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %%
percent of men or males is larger than femles  in terms of winning Medals

# %%
sns.countplot(data=df,x='Season',hue='Sex')
# Out:
# <AxesSubplot:xlabel='Season', ylabel='count'>

# %% [markdown]
# ### max number of participants from one country along the tournament

# %%
df['NOC'].value_counts().head()
# Out:
# USA    18853
# FRA    12758
# GBR    12256
# ITA    10715
# GER     9830
# Name: NOC, dtype: int64

# %%
df['Team'].value_counts().head()
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Name: Team, dtype: int64

# %% [markdown]
# ### MIN number of participants from one country

# %%
df['NOC'].value_counts().tail()
# Out:
# YMD    5
# SSD    3
# UNK    2
# NBO    2
# NFL    1
# Name: NOC, dtype: int64

# %% [markdown]
# ## average age for males and females

# %%
df.groupby(['Sex'])['Age'].mean()
# Out:
# Sex
# F    23.732881
# M    26.277562
# Name: Age, dtype: float64

# %% [markdown]
# ## oldest participant

# %%
df[df['Age']==df['Age'].max()]
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 257054  United States  USA  1928 Summer  1928  Summer  Amsterdam
#
#                    Sport                                        Event Medal
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues   NaN

# %% [markdown]
# ## youngest participant

# %%
df[df['Age']==df['Age'].min()]
# Out:
#            ID                Name Sex   Age  Height  Weight  \
# 142882  71691  Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season    City  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer  Athina
#
#              Sport                                  Event   Medal
# 142882  Gymnastics  Gymnastics Men's Parallel Bars, Teams  Bronze

# %%
df['Games'].value_counts()
# Out:
# 2000 Summer    13821
# 1996 Summer    13780
# 2016 Summer    13688
# 2008 Summer    13602
# 2004 Summer    13443
# 1992 Summer    12977
# 2012 Summer    12920
# 1988 Summer    12037
# 1972 Summer    10304
# 1984 Summer     9454
# 1976 Summer     8641
# 1968 Summer     8588
# 1952 Summer     8270
# 1960 Summer     8119
# 1964 Summer     7702
# 1980 Summer     7191
# 1936 Summer     6506
# 1948 Summer     6405
# 1924 Summer     5233
# 1956 Summer     5127
# 1928 Summer     4992
# 2014 Winter     4891
# 2010 Winter     4402
# 2006 Winter     4382
# 1920 Summer     4292
# 2002 Winter     4109
# 1912 Summer     4040
# 1998 Winter     3605
# 1992 Winter     3436
# 1994 Winter     3160
# 1908 Summer     3101
# 1932 Summer     2969
# 1988 Winter     2639
# 1984 Winter     2134
# 1900 Summer     1936
# 1968 Winter     1891
# 1976 Winter     1861
# 1964 Winter     1778
# 1980 Winter     1746
# 1906 Summer     1733
# 1972 Winter     1655
# 1956 Winter     1307
# 1904 Summer     1301
# ...

# %%
plt.figure(figsize=(7,7))
sns.histplot(data=df['Age'],kde=False,bins=30)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(x='Sex',y='Age',hue='Medal',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
df[df['Height']==df['Height'].max()]
# Out:
#             ID      Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 265040  132627  Yao Ming   M  20.0   226.0   141.0  China  CHN  2000 Summer
# 265041  132627  Yao Ming   M  23.0   226.0   141.0  China  CHN  2004 Summer
# 265042  132627  Yao Ming   M  27.0   226.0   141.0  China  CHN  2008 Summer
#
#         Year  Season     City       Sport                        Event Medal
# 265040  2000  Summer   Sydney  Basketball  Basketball Men's Basketball   NaN
# 265041  2004  Summer   Athina  Basketball  Basketball Men's Basketball   NaN
# 265042  2008  Summer  Beijing  Basketball  Basketball Men's Basketball   NaN

# %%
df['Name'].value_counts()
# Out:
# Robert Tait McKenzie        58
# Heikki Ilmari Savolainen    39
# Joseph "Josy" Stoffel       38
# Ioannis Theofilakis         36
# Takashi Ono                 33
#                             ..
# Fang Yanqiao                 1
# Sandra "Sandy" Beasley       1
# Kirsten Lawton               1
# Urban Cleve                  1
# Nils Edvard Svrd             1
# Name: Name, Length: 134732, dtype: int64

# %%
df[df['Name']=='Robert Tait McKenzie']
# Out:
#            ID                  Name Sex   Age  Height  Weight    Team  NOC  \
# 154798  77710  Robert Tait McKenzie   M  44.0     NaN     NaN  Canada  CAN
# 154799  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154800  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154801  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154802  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154803  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154804  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154805  77710  Robert Tait McKenzie   M  60.0     NaN     NaN  Canada  CAN
# 154806  77710  Robert Tait McKenzie   M  65.0     NaN     NaN  Canada  CAN
# 154807  77710  Robert Tait McKenzie   M  65.0     NaN     NaN  Canada  CAN
# 154808  77710  Robert Tait McKenzie   M  65.0     NaN     NaN  Canada  CAN
# ...

# %%
data=pd.read_csv('athlete_events.csv')

# %%
data.sort_values(by='Name',inplace=True)

# %%
(data.isnull().sum()/len(df))*100
# Out:
# ID         0.000000
# Name       0.000000
# Sex        0.000000
# Age        3.494445
# Height    22.193821
# Weight    23.191180
# Team       0.000000
# NOC        0.000000
# Games      0.000000
# Year       0.000000
# Season     0.000000
# City       0.000000
# Sport      0.000000
# Event      0.000000
# Medal     85.326207
# dtype: float64

# %% [markdown]
# ### Age, height and weight can't be removed
# ### Medal shall be removed

# %%
data['Age'].fillna(df['Age'].median(),inplace=True)

# %%
data['Height'].fillna(df['Height'].median(),inplace=True)

# %%
data['Weight'].fillna(df['Weight'].median(),inplace=True)

# %%
(data.isnull().sum()/len(df))*100
# Out:
# ID         0.000000
# Name       0.000000
# Sex        0.000000
# Age        0.000000
# Height     0.000000
# Weight     0.000000
# Team       0.000000
# NOC        0.000000
# Games      0.000000
# Year       0.000000
# Season     0.000000
# City       0.000000
# Sport      0.000000
# Event      0.000000
# Medal     85.326207
# dtype: float64

# %%
data.drop(['Medal'],axis=1,inplace=True)

# %%
(data.isnull().sum()/len(df))*100
# Out:
# ID        0.0
# Name      0.0
# Sex       0.0
# Age       0.0
# Height    0.0
# Weight    0.0
# Team      0.0
# NOC       0.0
# Games     0.0
# Year      0.0
# Season    0.0
# City      0.0
# Sport     0.0
# Event     0.0
# dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 1560 to 102956
# Data columns (total 14 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     271116 non-null  float64
#  4   Height  271116 non-null  float64
#  5   Weight  271116 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 39.1+ MB
